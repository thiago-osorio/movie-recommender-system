# %% [markdown]
# ###Instalando Bibliotecas

# %%
# !pip install tmdbv3api

# %% [markdown]
# ###Importando Bibliotecas

# %%
import os, requests
import pandas as pd
from tmdbv3api import TMDb, Movie
from numpy import NaN

# %% [markdown]
# ####Definindo parâmetros da API

# %%
tmdb = TMDb()
movie = Movie()
tmdb.api_key = 'c752658cbea631866744f576a4013cd1'

# %% [markdown]
# ###Funções para localizar as Informações dos Filmes

# %% [markdown]
# ####Pela biblioteca TMDbV3API

# %%
def get_id_movie(title_movie):
    res = movie.search(title_movie)
    return res[0].id

# %% [markdown]
# ####Pela API da TMDb

# %%
def get_adult(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['adult']

def get_belongs_to_collection(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['belongs_to_collection']

def get_budget(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['budget']

def get_genres(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['genres']

def get_homepage(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['homepage']

def get_imdb_id(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['imdb_id']

def get_original_language(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['original_language']

def get_overview(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['overview']

def get_popularity(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['popularity']

def get_poster_path(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['poster_path']

def get_production_companies(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['production_companies']

def get_production_countries(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['production_countries']

def get_release_date(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['release_date']

def get_revenue(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['revenue']

def get_runtime(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['runtime']

def get_spoken_languages(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['spoken_languages']

def get_status(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['status']

def get_tagline(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['tagline']

def get_title(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['title']

def get_video(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['video']

def get_vote_average(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['vote_average']
    
def get_vote_count(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['vote_count']

def get_keywords(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}/keywords?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    try:
      return data_json['keywords']
    except:
      return NaN

def get_cast(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}/credits?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['cast']

def get_crew(movie_id):
    response = requests.get('https://api.themoviedb.org/3/movie/{}/credits?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json['crew']

# %% [markdown]
# ###Criando a lista dos filmes de 2018 a 2021
# Importante passo pois no arquivo CSV temos somente as informações anteriores a 2018

# %%
urls = ['https://en.wikipedia.org/wiki/List_of_American_films_of_2018', 
'https://en.wikipedia.org/wiki/List_of_American_films_of_2019', 
'https://en.wikipedia.org/wiki/List_of_American_films_of_2020',
'https://en.wikipedia.org/wiki/List_of_American_films_of_2021',
'https://en.wikipedia.org/wiki/List_of_American_films_of_2022']

df_concat = pd.DataFrame({})
for i in range(4):
    for j in range(2,7):
        df = pd.read_html(str(urls[i]), header = 0)[j]
        df_concat = pd.concat([df_concat, df], ignore_index=True)

df_concat = df_concat.filter(['Title'], axis = 1)

# %% [markdown]
# ###Tratando os Dados
# Ajustando nome das colunas, dados faltantes e filmes com o nome errado

# %%
df_concat.replace(regex={r'The SpongeBob Movie: Sponge on the Run.*':'The SpongeBob Movie: Sponge on the Run'}, inplace= True)
df_concat.replace(regex={r'Finding(.){7}':'Finding Ohana'}, inplace= True)
df_concat = df_concat[df_concat['Title'].notna()]

df_concat.rename(columns={'Title':'original_title'}, inplace= True)

# %% [markdown]
# ###Buscando as informações dos Filmes de 2018 a 2021

# %% [markdown]
# ####ID (pela biblioteca TMDbV3API

# %%
df_concat['id'] = df_concat['original_title'].map(lambda x: get_id_movie(str(x)))

# %% [markdown]
# ####Outras informações pela API da TMDb

# %%
df_concat['adult'] = df_concat['id'].map(lambda x: get_adult(x))
df_concat['belongs_to_collection'] = df_concat['id'].map(lambda x: get_belongs_to_collection(x))
df_concat['budget'] = df_concat['id'].map(lambda x: get_budget(x))
df_concat['genres'] = df_concat['id'].map(lambda x: get_genres(x))
df_concat['homepage'] = df_concat['id'].map(lambda x: get_homepage(x))
df_concat['imdb_id'] = df_concat['id'].map(lambda x: get_imdb_id(x))
df_concat['original_language'] = df_concat['id'].map(lambda x: get_original_language(x))
df_concat['overview'] = df_concat['id'].map(lambda x: get_overview(x))
df_concat['popularity'] = df_concat['id'].map(lambda x: get_popularity(x))
df_concat['poster_path'] = df_concat['id'].map(lambda x: get_poster_path(x))
df_concat['production_companies'] = df_concat['id'].map(lambda x: get_production_companies(x))
df_concat['production_countries'] = df_concat['id'].map(lambda x: get_production_countries(x))
df_concat['release_date'] = df_concat['id'].map(lambda x: get_release_date(x))
df_concat['revenue'] = df_concat['id'].map(lambda x: get_revenue(x))
df_concat['runtime'] = df_concat['id'].map(lambda x: get_runtime(x))
df_concat['spoken_languages'] = df_concat['id'].map(lambda x: get_spoken_languages(x))
df_concat['status'] = df_concat['id'].map(lambda x: get_status(x))
df_concat['tagline'] = df_concat['id'].map(lambda x: get_tagline(x))
df_concat['title'] = df_concat['id'].map(lambda x: get_title(x))
df_concat['video'] = df_concat['id'].map(lambda x: get_video(x))
df_concat['vote_average'] = df_concat['id'].map(lambda x: get_vote_average(x))
df_concat['vote_count'] = df_concat['id'].map(lambda x: get_vote_count(x))
df_concat['keywords'] = df_concat['id'].map(lambda x: get_keywords(x))
df_concat['cast'] = df_concat['id'].map(lambda x: get_cast(x))
df_concat['crew'] = df_concat['id'].map(lambda x: get_crew(x))

# %%
df_concat.head()
# Out:
#             original_title      id  adult  \
# 0  Insidious: The Last Key  406563  False
# 1         The Strange Ones  426258  False
# 2                 Stratton  348389  False
# 3            Sweet Country  468210  False
# 4             The Commuter  399035  False
#
#                                belongs_to_collection    budget  \
# 0  {'id': 228446, 'name': 'Insidious Collection',...  10000000
# 1                                               None         0
# 2                                               None         0
# 3                                               None         0
# 4                                               None  30000000
#
#                                               genres  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
# ...

# %% [markdown]
# ###Carregando o DataSet dos Filmes

# %%
df_movies = pd.read_csv('/content/movies_metadata.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ####Fazendo um Merge do DataSet do Filme com o DataSet das Keywords e dos Créditos

# %%
df_credits = pd.read_csv('/content/credits.csv')
df_keywords = pd.read_csv('/content/keywords.csv')

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
for i in df_movies['id']:
  try:
    int(i)
  except:
    print(i)
# Out:
# 1997-08-20
# 2012-09-29
# 2014-01-01

# %%
df_movies.loc[df_movies['id'] == '1997-08-20']
# Out:
#                      adult belongs_to_collection  \
# 19730   - Written by Ørnås              0.065736
#
#                                  budget  \
# 19730  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        ... release_date revenue runtime spoken_languages status  tagline  \
# 19730  ...            1     NaN     NaN              NaN    NaN      NaN
#
#        title video vote_average vote_count
# 19730    NaN   NaN          NaN        NaN
#
# [1 rows x 24 columns]

# %%
df_movies.loc[df_movies['id'] == '2012-09-29']
# Out:
#                                                    adult  \
# 29503   Rune Balot goes to a casino connected to the ...
#
#       belongs_to_collection                            budget  \
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
#
#                                                   genres  \
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
#
#                                                 homepage          id imdb_id  \
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
#
#       original_language                        original_title  overview  ...  \
# 29503              68.0  [{'iso_639_1': 'ja', 'name': '日本語'}]  Released  ...
#
#       release_date revenue runtime spoken_languages status  tagline  title  \
# 29503           12     NaN     NaN              NaN    NaN      NaN    NaN
#
#       video vote_average vote_count
# 29503   NaN          NaN        NaN
#
# [1 rows x 24 columns]

# %%
df_movies.loc[df_movies['id'] == '2014-01-01']
# Out:
#                                                    adult  \
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                        homepage          id imdb_id  \
# 35587  [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
#
#       original_language                            original_title  overview  \
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        ... release_date revenue runtime spoken_languages status  tagline  \
# 35587  ...           22     NaN     NaN              NaN    NaN      NaN
#
#        title video vote_average vote_count
# 35587    NaN   NaN          NaN        NaN
#
# [1 rows x 24 columns]

# %%
df_movies.drop(labels=[19730,29503, 35587], axis = 0, inplace = True)

# %%
df_movies['id'] = df_movies['id'].astype('int64')

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45463 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  object
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  object
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  object
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
# ...

# %%
df_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
df_keywords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46419 entries, 0 to 46418
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        46419 non-null  int64
#  1   keywords  46419 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 725.4+ KB

# %%
df_merged = df_keywords.merge(df_credits, how='left', on='id')

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46496 entries, 0 to 46495
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        46496 non-null  int64
#  1   keywords  46496 non-null  object
#  2   cast      46496 non-null  object
#  3   crew      46496 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df_movies = df_movies.merge(df_merged, on='id', how='left')

# %%
df_movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# ###Concatenando os DataFrames

# %%
df_final = pd.concat([df_movies, df_concat], ignore_index=True)

# %% [markdown]
# ###Exportando o DataFrame Concatenado

# %%
df_final.to_csv('df_final.csv', index = False, header = True)
