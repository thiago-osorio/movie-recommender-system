# %% [markdown]
# # Importando Bibliotecas

# %%
import gc
import os, requests
import pandas as pd
from numpy import NaN
from dotenv import load_dotenv
from tmdbv3api import TMDb, Movie

# %% [markdown]
# # Funções

# %%
def get_id_movie(title_movie):
    try:
        res = movie.search(title_movie)
        return int(res[0].id)
    except:
        return NaN

# %% [markdown]
# # Extração

# %%
tmdb = TMDb()
movie = Movie()

# %%
load_dotenv('../content/keys.env')
tmdb.api_key = os.getenv('api_key')

# %%
urls = [
    'https://en.wikipedia.org/wiki/List_of_American_films_of_2018', 
    'https://en.wikipedia.org/wiki/List_of_American_films_of_2019', 
    'https://en.wikipedia.org/wiki/List_of_American_films_of_2020',
    'https://en.wikipedia.org/wiki/List_of_American_films_of_2021',
    'https://en.wikipedia.org/wiki/List_of_American_films_of_2022',
    'https://en.wikipedia.org/wiki/List_of_American_films_of_2023'
    ]

df = pd.DataFrame()
for i in range(4):
    for j in range(2,7):
        temp_df = pd.read_html(str(urls[i]), header = 0)[j]
        df = pd.concat([temp_df, df], ignore_index=True)

df = df.filter(['Title'], axis = 1)

# %%
df.dropna(inplace=True)
df
# Out:
#                                     Title
# 1             Venom: Let There Be Carnage
# 2               The Many Saints of Newark
# 3                     The Addams Family 2
# 4                              Bingo Hell
# 5                          Black as Night
# ...                                   ...
# 1155                     Ready Player One
# 1156               Tyler Perry's Acrimony
# 1157  God's Not Dead: A Light in Darkness
# 1158                               Gemini
# 1159                  The Last Movie Star
#
# [1155 rows x 1 columns]

# %%
df.replace(regex={r'The SpongeBob Movie: Sponge on the Run.*':'The SpongeBob Movie: Sponge on the Run'}, inplace= True)
df.replace(regex={r'Finding(.){7}':'Finding Ohana'}, inplace= True)

df.rename(columns={'Title':'original_title'}, inplace= True)

df
# Out:
#                            original_title
# 1             Venom: Let There Be Carnage
# 2               The Many Saints of Newark
# 3                     The Addams Family 2
# 4                              Bingo Hell
# 5                          Black as Night
# ...                                   ...
# 1155                     Ready Player One
# 1156               Tyler Perry's Acrimony
# 1157  God's Not Dead: A Light in Darkness
# 1158                               Gemini
# 1159                  The Last Movie Star
#
# [1155 rows x 1 columns]

# %% [markdown]
# # Enriquecimento

# %%
df['id'] = df['original_title'].map(lambda x: get_id_movie(str(x)))
df.dropna(subset='id', inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                            original_title        id
# 0             Venom: Let There Be Carnage  580489.0
# 1               The Many Saints of Newark  524369.0
# 2                     The Addams Family 2  639721.0
# 3                              Bingo Hell  802226.0
# 4                          Black as Night  767504.0
# ...                                   ...       ...
# 1148                     Ready Player One  333339.0
# 1149               Tyler Perry's Acrimony  464502.0
# 1150  God's Not Dead: A Light in Darkness  454286.0
# 1151                               Gemini  412302.0
# 1152                  The Last Movie Star  451204.0
#
# [1153 rows x 2 columns]

# %%
ids = df['id'].astype(int).tolist()

# %%
features_df = pd.DataFrame()

for movie_id in ids:
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    try:
        temp_df = pd.json_normalize(data_json)
        features_df = pd.concat([features_df, temp_df], ignore_index=True)
        del temp_df
        gc.collect()
    except:
        features_df = features_df

features_df
# Out:
#       adult                     backdrop_path     budget  \
# 0     False  /vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg  110000000
# 1     False  /hrzoy8vvUrxQixOM11pwW9AX7Bu.jpg          0
# 2     False  /9e6wp707XMouPG939o2fHunXXJR.jpg          0
# 3     False  /4lmDTjpZNf5S1DlFzIbuQ7dus7p.jpg          0
# 4     False  /8y556k6ihZeYv2OXcFHTdMJKp1m.jpg          0
# ...     ...                               ...        ...
# 1148  False  /dbrLfmFNFEJWv8rLnjpgCKlXWSy.jpg  175000000
# 1149  False  /h9USMzm43BZyUXc45OZAPlPBUjZ.jpg   20000000
# 1150  False  /gGBE24xD5NdMqvkJJEzP04jtFG9.jpg          0
# 1151  False  /eReiiUBlDgF2dAtKkpxzzK6H8t2.jpg          0
# 1152  False  /ndJCn2EGgoCZdArIYYuKrHbmQPn.jpg          0
#
#                                                  genres  \
# 0     [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1                         [{'id': 80, 'name': 'Crime'}]
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 4     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...                                                 ...
# 1148  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1149                   [{'id': 53, 'name': 'Thriller'}]
# 1150                      [{'id': 18, 'name': 'Drama'}]
# 1151  [{'id': 9648, 'name': 'Mystery'}, {'id': 80, '...
# 1152                      [{'id': 18, 'name': 'Drama'}]
#
#                                         homepage      id     imdb_id  \
# 0                        https://www.venom.movie  580489   tt7097896
# 1     https://www.themanysaintsofnewarkmovie.com  524369   tt8110232
# 2     https://mgm.com/movies/the-addams-family-2  639721  tt11125620
# 3                                                 802226  tt13372992
# 4                                                 767504  tt13372884
# ...                                          ...     ...         ...
# 1148              http://readyplayeronemovie.com  333339   tt1677720
# 1149                 https://www.acrimony.movie/  464502   tt6063050
# 1150                                              454286   tt6652708
# 1151              https://www.geminithefilm.com/  412302   tt5795086
# 1152                    http://lastmoviestar.com  451204   tt5836316
#
#      original_language                       original_title  \
# 0                   en          Venom: Let There Be Carnage
# 1                   en            The Many Saints of Newark
# 2                   en                  The Addams Family 2
# 3                   en                           Bingo Hell
# 4                   en                       Black as Night
# ...                ...                                  ...
# 1148                en                     Ready Player One
# 1149                en                             Acrimony
# 1150                en  God's Not Dead: A Light in Darkness
# 1151                en                               Gemini
# 1152                en                  The Last Movie Star
#
#                                                overview  ...  \
# 0     After finding a host body in investigative rep...  ...
# 1     Young Anthony Soprano is growing up in one of ...  ...
# 2     The Addams get tangled up in more wacky advent...  ...
# 3     In the Barrio of Oak Springs live a strong and...  ...
# 4     A teenage girl with self-esteem issues finds c...  ...
# ...                                                 ...  ...
# 1148  When the creator of a popular video game syste...  ...
# 1149  A faithful wife takes action when it becomes c...  ...
# 1150  Pastor Dave  responds to the unimaginable trag...  ...
# 1151  A heinous crime tests the complex relationship...  ...
# 1152  An aging screen icon gets lured into accepting...  ...
#
#                                       tagline  \
# 0
# 1                      Who made Tony Soprano?
# 2                   Unhappy to see you again.
# 3                      Are you feeling lucky?
# 4                  Find your own way to slay.
# ...                                       ...
# 1148                 A better reality awaits.
# 1149                        Hell Hath No Fury
# 1150
# 1151  It’s all there if you know how to look.
# 1152                 The best is yet to come.
#
#                                     title  video vote_average vote_count  \
# 0             Venom: Let There Be Carnage  False        6.880       8642
# 1               The Many Saints of Newark  False        6.475        508
# 2                     The Addams Family 2  False        7.073       1079
# 3                              Bingo Hell  False        4.895         95
# 4                          Black as Night  False        5.621        112
# ...                                   ...    ...          ...        ...
# 1148                     Ready Player One  False        7.615      13879
# 1149                             Acrimony  False        6.800        346
# 1150  God's Not Dead: A Light in Darkness  False        6.872        179
# 1151                               Gemini  False        5.500        118
# 1152                  The Last Movie Star  False        6.494         87
#
#       belongs_to_collection.id               belongs_to_collection.name  \
# 0                     558216.0                         Venom Collection
# 1                          NaN                                      NaN
# 2                     750822.0  The Addams Family (Animated) Collection
# 3                          NaN                                      NaN
# 4                          NaN                                      NaN
# ...                        ...                                      ...
# 1148                       NaN                                      NaN
# 1149                       NaN                                      NaN
# 1150                  409343.0                God's Not Dead Collection
# 1151                       NaN                                      NaN
# 1152                       NaN                                      NaN
#
#      belongs_to_collection.poster_path belongs_to_collection.backdrop_path  \
# 0     /4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg    /rhLspFB1B8ZCkWEHFYmc3NKagzq.jpg
# 1                                  NaN                                 NaN
# 2     /392omPB0NlpsxEqJkagjdUJeuhb.jpg    /3VfaWlf8wJewGsKSTYhJsY0pnNx.jpg
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# ...                                ...                                 ...
# 1148                               NaN                                 NaN
# 1149                               NaN                                 NaN
# 1150  /bR20AQt3ycgQ6frHYF5tkomwbFp.jpg    /rX1S0AZpvLNFURBqMFXrXIj4Vmm.jpg
# 1151                               NaN                                 NaN
# 1152                               NaN                                 NaN
#
#      belongs_to_collection
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 1148                   NaN
# 1149                   NaN
# 1150                   NaN
# 1151                   NaN
# 1152                   NaN
#
# [1153 rows x 29 columns]

# %%
credits_df = pd.DataFrame()

for movie_id in ids:
    response = requests.get('https://api.themoviedb.org/3/movie/{}/credits?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    try:
        temp_df = pd.json_normalize(data_json)
        credits_df = pd.concat([credits_df, temp_df], ignore_index=True)
        del temp_df
        gc.collect()
    except:
        credits_df = credits_df

credits_df
# Out:
#           id                                               cast  \
# 0     580489  [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1     524369  [{'adult': False, 'gender': 2, 'id': 4941, 'kn...
# 2     639721  [{'adult': False, 'gender': 2, 'id': 25072, 'k...
# 3     802226  [{'adult': False, 'gender': 1, 'id': 270, 'kno...
# 4     767504  [{'adult': False, 'gender': 1, 'id': 1317152, ...
# ...      ...                                                ...
# 1148  333339  [{'adult': False, 'gender': 2, 'id': 1034681, ...
# 1149  464502  [{'adult': False, 'gender': 1, 'id': 40036, 'k...
# 1150  454286  [{'adult': False, 'gender': 2, 'id': 116431, '...
# 1151  412302  [{'adult': False, 'gender': 1, 'id': 1345418, ...
# 1152  451204  [{'adult': False, 'gender': 2, 'id': 16475, 'k...
#
#                                                    crew
# 0     [{'adult': False, 'gender': 2, 'id': 149, 'kno...
# 1     [{'adult': False, 'gender': 2, 'id': 2100, 'kn...
# 2     [{'adult': False, 'gender': 2, 'id': 5359, 'kn...
# 3     [{'adult': False, 'gender': 2, 'id': 84348, 'k...
# 4     [{'adult': False, 'gender': 0, 'id': 24512, 'k...
# ...                                                 ...
# 1148  [{'adult': False, 'gender': 2, 'id': 37, 'know...
# 1149  [{'adult': False, 'gender': 2, 'id': 49911, 'k...
# 1150  [{'adult': False, 'gender': 2, 'id': 24968, 'k...
# 1151  [{'adult': False, 'gender': 0, 'id': 222365, '...
# 1152  [{'adult': False, 'gender': 0, 'id': 45054, 'k...
#
# [1153 rows x 3 columns]

# %%
keywords_df = pd.DataFrame()

for movie_id in ids:
    response = requests.get('https://api.themoviedb.org/3/movie/{}/keywords?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    try:
        temp_df = pd.json_normalize(data_json)
        keywords_df = pd.concat([keywords_df, temp_df], ignore_index=True)
        del temp_df
        gc.collect()
    except:
        keywords_df = keywords_df

keywords_df
# Out:
#           id                                           keywords
# 0     580489  [{'id': 1701, 'name': 'hero'}, {'id': 2095, 'n...
# 1     524369  [{'id': 586, 'name': 'new jersey'}, {'id': 700...
# 2     639721                                                 []
# 3     802226                   [{'id': 10936, 'name': 'bingo'}]
# 4     767504  [{'id': 2411, 'name': 'new orleans, louisiana'...
# ...      ...                                                ...
# 1148  333339  [{'id': 282, 'name': 'video game'}, {'id': 818...
# 1149  464502                  [{'id': 9748, 'name': 'revenge'}]
# 1150  454286  [{'id': 14765, 'name': 'church'}, {'id': 17943...
# 1151  412302  [{'id': 5306, 'name': 'boss'}, {'id': 12396, '...
# 1152  451204  [{'id': 5609, 'name': 'nostalgia'}, {'id': 109...
#
# [1153 rows x 2 columns]

# %%
df = df.merge(features_df.drop('original_title', axis=1), how='left', on='id')
df = df.merge(credits_df, how='left', on='id')
df = df.merge(keywords_df, how='left', on='id')
df
# Out:
#                            original_title        id  adult  \
# 0             Venom: Let There Be Carnage  580489.0  False
# 1               The Many Saints of Newark  524369.0  False
# 2                     The Addams Family 2  639721.0  False
# 3                              Bingo Hell  802226.0  False
# 4                          Black as Night  767504.0  False
# ...                                   ...       ...    ...
# 1204                     Ready Player One  333339.0  False
# 1205               Tyler Perry's Acrimony  464502.0  False
# 1206  God's Not Dead: A Light in Darkness  454286.0  False
# 1207                               Gemini  412302.0  False
# 1208                  The Last Movie Star  451204.0  False
#
#                          backdrop_path     budget  \
# 0     /vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg  110000000
# 1     /hrzoy8vvUrxQixOM11pwW9AX7Bu.jpg          0
# 2     /9e6wp707XMouPG939o2fHunXXJR.jpg          0
# 3     /4lmDTjpZNf5S1DlFzIbuQ7dus7p.jpg          0
# 4     /8y556k6ihZeYv2OXcFHTdMJKp1m.jpg          0
# ...                                ...        ...
# 1204  /dbrLfmFNFEJWv8rLnjpgCKlXWSy.jpg  175000000
# 1205  /h9USMzm43BZyUXc45OZAPlPBUjZ.jpg   20000000
# 1206  /gGBE24xD5NdMqvkJJEzP04jtFG9.jpg          0
# 1207  /eReiiUBlDgF2dAtKkpxzzK6H8t2.jpg          0
# 1208  /ndJCn2EGgoCZdArIYYuKrHbmQPn.jpg          0
#
#                                                  genres  \
# 0     [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1                         [{'id': 80, 'name': 'Crime'}]
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 4     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...                                                 ...
# 1204  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1205                   [{'id': 53, 'name': 'Thriller'}]
# 1206                      [{'id': 18, 'name': 'Drama'}]
# 1207  [{'id': 9648, 'name': 'Mystery'}, {'id': 80, '...
# 1208                      [{'id': 18, 'name': 'Drama'}]
#
#                                         homepage     imdb_id  \
# 0                        https://www.venom.movie   tt7097896
# 1     https://www.themanysaintsofnewarkmovie.com   tt8110232
# 2     https://mgm.com/movies/the-addams-family-2  tt11125620
# 3                                                 tt13372992
# 4                                                 tt13372884
# ...                                          ...         ...
# 1204              http://readyplayeronemovie.com   tt1677720
# 1205                 https://www.acrimony.movie/   tt6063050
# 1206                                               tt6652708
# 1207              https://www.geminithefilm.com/   tt5795086
# 1208                    http://lastmoviestar.com   tt5836316
#
#      original_language                                           overview  \
# 0                   en  After finding a host body in investigative rep...
# 1                   en  Young Anthony Soprano is growing up in one of ...
# 2                   en  The Addams get tangled up in more wacky advent...
# 3                   en  In the Barrio of Oak Springs live a strong and...
# 4                   en  A teenage girl with self-esteem issues finds c...
# ...                ...                                                ...
# 1204                en  When the creator of a popular video game syste...
# 1205                en  A faithful wife takes action when it becomes c...
# 1206                en  Pastor Dave  responds to the unimaginable trag...
# 1207                en  A heinous crime tests the complex relationship...
# 1208                en  An aging screen icon gets lured into accepting...
#
#       ...  vote_average vote_count belongs_to_collection.id  \
# 0     ...         6.880       8642                 558216.0
# 1     ...         6.475        508                      NaN
# 2     ...         7.073       1079                 750822.0
# 3     ...         4.895         95                      NaN
# 4     ...         5.621        112                      NaN
# ...   ...           ...        ...                      ...
# 1204  ...         7.615      13879                      NaN
# 1205  ...         6.800        346                      NaN
# 1206  ...         6.872        179                 409343.0
# 1207  ...         5.500        118                      NaN
# 1208  ...         6.494         87                      NaN
#
#                    belongs_to_collection.name  \
# 0                            Venom Collection
# 1                                         NaN
# 2     The Addams Family (Animated) Collection
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1204                                      NaN
# 1205                                      NaN
# 1206                God's Not Dead Collection
# 1207                                      NaN
# 1208                                      NaN
#
#      belongs_to_collection.poster_path  belongs_to_collection.backdrop_path  \
# 0     /4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg     /rhLspFB1B8ZCkWEHFYmc3NKagzq.jpg
# 1                                  NaN                                  NaN
# 2     /392omPB0NlpsxEqJkagjdUJeuhb.jpg     /3VfaWlf8wJewGsKSTYhJsY0pnNx.jpg
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
# ...                                ...                                  ...
# 1204                               NaN                                  NaN
# 1205                               NaN                                  NaN
# 1206  /bR20AQt3ycgQ6frHYF5tkomwbFp.jpg     /rX1S0AZpvLNFURBqMFXrXIj4Vmm.jpg
# 1207                               NaN                                  NaN
# 1208                               NaN                                  NaN
#
#       belongs_to_collection  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1204                    NaN
# 1205                    NaN
# 1206                    NaN
# 1207                    NaN
# 1208                   None
#
#                                                    cast  \
# 0     [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1     [{'adult': False, 'gender': 2, 'id': 4941, 'kn...
# 2     [{'adult': False, 'gender': 2, 'id': 25072, 'k...
# 3     [{'adult': False, 'gender': 1, 'id': 270, 'kno...
# 4     [{'adult': False, 'gender': 1, 'id': 1317152, ...
# ...                                                 ...
# 1204  [{'adult': False, 'gender': 2, 'id': 1034681, ...
# 1205  [{'adult': False, 'gender': 1, 'id': 40036, 'k...
# 1206  [{'adult': False, 'gender': 2, 'id': 116431, '...
# 1207  [{'adult': False, 'gender': 1, 'id': 1345418, ...
# 1208  [{'adult': False, 'gender': 2, 'id': 16475, 'k...
#
#                                                    crew  \
# 0     [{'adult': False, 'gender': 2, 'id': 149, 'kno...
# 1     [{'adult': False, 'gender': 2, 'id': 2100, 'kn...
# 2     [{'adult': False, 'gender': 2, 'id': 5359, 'kn...
# 3     [{'adult': False, 'gender': 2, 'id': 84348, 'k...
# 4     [{'adult': False, 'gender': 0, 'id': 24512, 'k...
# ...                                                 ...
# 1204  [{'adult': False, 'gender': 2, 'id': 37, 'know...
# 1205  [{'adult': False, 'gender': 2, 'id': 49911, 'k...
# 1206  [{'adult': False, 'gender': 2, 'id': 24968, 'k...
# 1207  [{'adult': False, 'gender': 0, 'id': 222365, '...
# 1208  [{'adult': False, 'gender': 0, 'id': 45054, 'k...
#
#                                                keywords
# 0     [{'id': 1701, 'name': 'hero'}, {'id': 2095, 'n...
# 1     [{'id': 586, 'name': 'new jersey'}, {'id': 700...
# 2                                                    []
# 3                      [{'id': 10936, 'name': 'bingo'}]
# 4     [{'id': 2411, 'name': 'new orleans, louisiana'...
# ...                                                 ...
# 1204  [{'id': 282, 'name': 'video game'}, {'id': 818...
# 1205                  [{'id': 9748, 'name': 'revenge'}]
# 1206  [{'id': 14765, 'name': 'church'}, {'id': 17943...
# 1207  [{'id': 5306, 'name': 'boss'}, {'id': 12396, '...
# 1208  [{'id': 5609, 'name': 'nostalgia'}, {'id': 109...
#
# [1209 rows x 32 columns]

# %%
belongs_to_collection_columns = ['belongs_to_collection.id','belongs_to_collection.name','belongs_to_collection.poster_path','belongs_to_collection.backdrop_path']

# %%
df['belongs_to_collection'] = df[belongs_to_collection_columns].values.tolist()
df
# Out:
#                            original_title        id  adult  \
# 0             Venom: Let There Be Carnage  580489.0  False
# 1               The Many Saints of Newark  524369.0  False
# 2                     The Addams Family 2  639721.0  False
# 3                              Bingo Hell  802226.0  False
# 4                          Black as Night  767504.0  False
# ...                                   ...       ...    ...
# 1204                     Ready Player One  333339.0  False
# 1205               Tyler Perry's Acrimony  464502.0  False
# 1206  God's Not Dead: A Light in Darkness  454286.0  False
# 1207                               Gemini  412302.0  False
# 1208                  The Last Movie Star  451204.0  False
#
#                          backdrop_path     budget  \
# 0     /vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg  110000000
# 1     /hrzoy8vvUrxQixOM11pwW9AX7Bu.jpg          0
# 2     /9e6wp707XMouPG939o2fHunXXJR.jpg          0
# 3     /4lmDTjpZNf5S1DlFzIbuQ7dus7p.jpg          0
# 4     /8y556k6ihZeYv2OXcFHTdMJKp1m.jpg          0
# ...                                ...        ...
# 1204  /dbrLfmFNFEJWv8rLnjpgCKlXWSy.jpg  175000000
# 1205  /h9USMzm43BZyUXc45OZAPlPBUjZ.jpg   20000000
# 1206  /gGBE24xD5NdMqvkJJEzP04jtFG9.jpg          0
# 1207  /eReiiUBlDgF2dAtKkpxzzK6H8t2.jpg          0
# 1208  /ndJCn2EGgoCZdArIYYuKrHbmQPn.jpg          0
#
#                                                  genres  \
# 0     [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1                         [{'id': 80, 'name': 'Crime'}]
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 4     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...                                                 ...
# 1204  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1205                   [{'id': 53, 'name': 'Thriller'}]
# 1206                      [{'id': 18, 'name': 'Drama'}]
# 1207  [{'id': 9648, 'name': 'Mystery'}, {'id': 80, '...
# 1208                      [{'id': 18, 'name': 'Drama'}]
#
#                                         homepage     imdb_id  \
# 0                        https://www.venom.movie   tt7097896
# 1     https://www.themanysaintsofnewarkmovie.com   tt8110232
# 2     https://mgm.com/movies/the-addams-family-2  tt11125620
# 3                                                 tt13372992
# 4                                                 tt13372884
# ...                                          ...         ...
# 1204              http://readyplayeronemovie.com   tt1677720
# 1205                 https://www.acrimony.movie/   tt6063050
# 1206                                               tt6652708
# 1207              https://www.geminithefilm.com/   tt5795086
# 1208                    http://lastmoviestar.com   tt5836316
#
#      original_language                                           overview  \
# 0                   en  After finding a host body in investigative rep...
# 1                   en  Young Anthony Soprano is growing up in one of ...
# 2                   en  The Addams get tangled up in more wacky advent...
# 3                   en  In the Barrio of Oak Springs live a strong and...
# 4                   en  A teenage girl with self-esteem issues finds c...
# ...                ...                                                ...
# 1204                en  When the creator of a popular video game syste...
# 1205                en  A faithful wife takes action when it becomes c...
# 1206                en  Pastor Dave  responds to the unimaginable trag...
# 1207                en  A heinous crime tests the complex relationship...
# 1208                en  An aging screen icon gets lured into accepting...
#
#       ...  vote_average vote_count belongs_to_collection.id  \
# 0     ...         6.880       8642                 558216.0
# 1     ...         6.475        508                      NaN
# 2     ...         7.073       1079                 750822.0
# 3     ...         4.895         95                      NaN
# 4     ...         5.621        112                      NaN
# ...   ...           ...        ...                      ...
# 1204  ...         7.615      13879                      NaN
# 1205  ...         6.800        346                      NaN
# 1206  ...         6.872        179                 409343.0
# 1207  ...         5.500        118                      NaN
# 1208  ...         6.494         87                      NaN
#
#                    belongs_to_collection.name  \
# 0                            Venom Collection
# 1                                         NaN
# 2     The Addams Family (Animated) Collection
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1204                                      NaN
# 1205                                      NaN
# 1206                God's Not Dead Collection
# 1207                                      NaN
# 1208                                      NaN
#
#      belongs_to_collection.poster_path  belongs_to_collection.backdrop_path  \
# 0     /4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg     /rhLspFB1B8ZCkWEHFYmc3NKagzq.jpg
# 1                                  NaN                                  NaN
# 2     /392omPB0NlpsxEqJkagjdUJeuhb.jpg     /3VfaWlf8wJewGsKSTYhJsY0pnNx.jpg
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
# ...                                ...                                  ...
# 1204                               NaN                                  NaN
# 1205                               NaN                                  NaN
# 1206  /bR20AQt3ycgQ6frHYF5tkomwbFp.jpg     /rX1S0AZpvLNFURBqMFXrXIj4Vmm.jpg
# 1207                               NaN                                  NaN
# 1208                               NaN                                  NaN
#
#                                   belongs_to_collection  \
# 0     [558216.0, Venom Collection, /4bXIKqdZIjR8wKgZ...
# 1                                  [nan, nan, nan, nan]
# 2     [750822.0, The Addams Family (Animated) Collec...
# 3                                  [nan, nan, nan, nan]
# 4                                  [nan, nan, nan, nan]
# ...                                                 ...
# 1204                               [nan, nan, nan, nan]
# 1205                               [nan, nan, nan, nan]
# 1206  [409343.0, God's Not Dead Collection, /bR20AQt...
# 1207                               [nan, nan, nan, nan]
# 1208                               [nan, nan, nan, nan]
#
#                                                    cast  \
# 0     [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1     [{'adult': False, 'gender': 2, 'id': 4941, 'kn...
# 2     [{'adult': False, 'gender': 2, 'id': 25072, 'k...
# 3     [{'adult': False, 'gender': 1, 'id': 270, 'kno...
# 4     [{'adult': False, 'gender': 1, 'id': 1317152, ...
# ...                                                 ...
# 1204  [{'adult': False, 'gender': 2, 'id': 1034681, ...
# 1205  [{'adult': False, 'gender': 1, 'id': 40036, 'k...
# 1206  [{'adult': False, 'gender': 2, 'id': 116431, '...
# 1207  [{'adult': False, 'gender': 1, 'id': 1345418, ...
# 1208  [{'adult': False, 'gender': 2, 'id': 16475, 'k...
#
#                                                    crew  \
# 0     [{'adult': False, 'gender': 2, 'id': 149, 'kno...
# 1     [{'adult': False, 'gender': 2, 'id': 2100, 'kn...
# 2     [{'adult': False, 'gender': 2, 'id': 5359, 'kn...
# 3     [{'adult': False, 'gender': 2, 'id': 84348, 'k...
# 4     [{'adult': False, 'gender': 0, 'id': 24512, 'k...
# ...                                                 ...
# 1204  [{'adult': False, 'gender': 2, 'id': 37, 'know...
# 1205  [{'adult': False, 'gender': 2, 'id': 49911, 'k...
# 1206  [{'adult': False, 'gender': 2, 'id': 24968, 'k...
# 1207  [{'adult': False, 'gender': 0, 'id': 222365, '...
# 1208  [{'adult': False, 'gender': 0, 'id': 45054, 'k...
#
#                                                keywords
# 0     [{'id': 1701, 'name': 'hero'}, {'id': 2095, 'n...
# 1     [{'id': 586, 'name': 'new jersey'}, {'id': 700...
# 2                                                    []
# 3                      [{'id': 10936, 'name': 'bingo'}]
# 4     [{'id': 2411, 'name': 'new orleans, louisiana'...
# ...                                                 ...
# 1204  [{'id': 282, 'name': 'video game'}, {'id': 818...
# 1205                  [{'id': 9748, 'name': 'revenge'}]
# 1206  [{'id': 14765, 'name': 'church'}, {'id': 17943...
# 1207  [{'id': 5306, 'name': 'boss'}, {'id': 12396, '...
# 1208  [{'id': 5609, 'name': 'nostalgia'}, {'id': 109...
#
# [1209 rows x 32 columns]

# %%
df.drop(belongs_to_collection_columns, axis=1, inplace=True)
df
# Out:
#                            original_title        id  adult  \
# 0             Venom: Let There Be Carnage  580489.0  False
# 1               The Many Saints of Newark  524369.0  False
# 2                     The Addams Family 2  639721.0  False
# 3                              Bingo Hell  802226.0  False
# 4                          Black as Night  767504.0  False
# ...                                   ...       ...    ...
# 1204                     Ready Player One  333339.0  False
# 1205               Tyler Perry's Acrimony  464502.0  False
# 1206  God's Not Dead: A Light in Darkness  454286.0  False
# 1207                               Gemini  412302.0  False
# 1208                  The Last Movie Star  451204.0  False
#
#                          backdrop_path     budget  \
# 0     /vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg  110000000
# 1     /hrzoy8vvUrxQixOM11pwW9AX7Bu.jpg          0
# 2     /9e6wp707XMouPG939o2fHunXXJR.jpg          0
# 3     /4lmDTjpZNf5S1DlFzIbuQ7dus7p.jpg          0
# 4     /8y556k6ihZeYv2OXcFHTdMJKp1m.jpg          0
# ...                                ...        ...
# 1204  /dbrLfmFNFEJWv8rLnjpgCKlXWSy.jpg  175000000
# 1205  /h9USMzm43BZyUXc45OZAPlPBUjZ.jpg   20000000
# 1206  /gGBE24xD5NdMqvkJJEzP04jtFG9.jpg          0
# 1207  /eReiiUBlDgF2dAtKkpxzzK6H8t2.jpg          0
# 1208  /ndJCn2EGgoCZdArIYYuKrHbmQPn.jpg          0
#
#                                                  genres  \
# 0     [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1                         [{'id': 80, 'name': 'Crime'}]
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 4     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...                                                 ...
# 1204  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1205                   [{'id': 53, 'name': 'Thriller'}]
# 1206                      [{'id': 18, 'name': 'Drama'}]
# 1207  [{'id': 9648, 'name': 'Mystery'}, {'id': 80, '...
# 1208                      [{'id': 18, 'name': 'Drama'}]
#
#                                         homepage     imdb_id  \
# 0                        https://www.venom.movie   tt7097896
# 1     https://www.themanysaintsofnewarkmovie.com   tt8110232
# 2     https://mgm.com/movies/the-addams-family-2  tt11125620
# 3                                                 tt13372992
# 4                                                 tt13372884
# ...                                          ...         ...
# 1204              http://readyplayeronemovie.com   tt1677720
# 1205                 https://www.acrimony.movie/   tt6063050
# 1206                                               tt6652708
# 1207              https://www.geminithefilm.com/   tt5795086
# 1208                    http://lastmoviestar.com   tt5836316
#
#      original_language                                           overview  \
# 0                   en  After finding a host body in investigative rep...
# 1                   en  Young Anthony Soprano is growing up in one of ...
# 2                   en  The Addams get tangled up in more wacky advent...
# 3                   en  In the Barrio of Oak Springs live a strong and...
# 4                   en  A teenage girl with self-esteem issues finds c...
# ...                ...                                                ...
# 1204                en  When the creator of a popular video game syste...
# 1205                en  A faithful wife takes action when it becomes c...
# 1206                en  Pastor Dave  responds to the unimaginable trag...
# 1207                en  A heinous crime tests the complex relationship...
# 1208                en  An aging screen icon gets lured into accepting...
#
#       ...    status                                  tagline  \
# 0     ...  Released
# 1     ...  Released                   Who made Tony Soprano?
# 2     ...  Released                Unhappy to see you again.
# 3     ...  Released                   Are you feeling lucky?
# 4     ...  Released               Find your own way to slay.
# ...   ...       ...                                      ...
# 1204  ...  Released                 A better reality awaits.
# 1205  ...  Released                        Hell Hath No Fury
# 1206  ...  Released
# 1207  ...  Released  It’s all there if you know how to look.
# 1208  ...  Released                 The best is yet to come.
#
#                                     title  video vote_average  vote_count  \
# 0             Venom: Let There Be Carnage  False        6.880        8642
# 1               The Many Saints of Newark  False        6.475         508
# 2                     The Addams Family 2  False        7.073        1079
# 3                              Bingo Hell  False        4.895          95
# 4                          Black as Night  False        5.621         112
# ...                                   ...    ...          ...         ...
# 1204                     Ready Player One  False        7.615       13879
# 1205                             Acrimony  False        6.800         346
# 1206  God's Not Dead: A Light in Darkness  False        6.872         179
# 1207                               Gemini  False        5.500         118
# 1208                  The Last Movie Star  False        6.494          87
#
#       belongs_to_collection  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1204                    NaN
# 1205                    NaN
# 1206                    NaN
# 1207                    NaN
# 1208                    NaN
#
#                                                    cast  \
# 0     [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1     [{'adult': False, 'gender': 2, 'id': 4941, 'kn...
# 2     [{'adult': False, 'gender': 2, 'id': 25072, 'k...
# 3     [{'adult': False, 'gender': 1, 'id': 270, 'kno...
# 4     [{'adult': False, 'gender': 1, 'id': 1317152, ...
# ...                                                 ...
# 1204  [{'adult': False, 'gender': 2, 'id': 1034681, ...
# 1205  [{'adult': False, 'gender': 1, 'id': 40036, 'k...
# 1206  [{'adult': False, 'gender': 2, 'id': 116431, '...
# 1207  [{'adult': False, 'gender': 1, 'id': 1345418, ...
# 1208  [{'adult': False, 'gender': 2, 'id': 16475, 'k...
#
#                                                    crew  \
# 0     [{'adult': False, 'gender': 2, 'id': 149, 'kno...
# 1     [{'adult': False, 'gender': 2, 'id': 2100, 'kn...
# 2     [{'adult': False, 'gender': 2, 'id': 5359, 'kn...
# 3     [{'adult': False, 'gender': 2, 'id': 84348, 'k...
# 4     [{'adult': False, 'gender': 0, 'id': 24512, 'k...
# ...                                                 ...
# 1204  [{'adult': False, 'gender': 2, 'id': 37, 'know...
# 1205  [{'adult': False, 'gender': 2, 'id': 49911, 'k...
# 1206  [{'adult': False, 'gender': 2, 'id': 24968, 'k...
# 1207  [{'adult': False, 'gender': 0, 'id': 222365, '...
# 1208  [{'adult': False, 'gender': 0, 'id': 45054, 'k...
#
#                                                keywords
# 0     [{'id': 1701, 'name': 'hero'}, {'id': 2095, 'n...
# 1     [{'id': 586, 'name': 'new jersey'}, {'id': 700...
# 2                                                    []
# 3                      [{'id': 10936, 'name': 'bingo'}]
# 4     [{'id': 2411, 'name': 'new orleans, louisiana'...
# ...                                                 ...
# 1204  [{'id': 282, 'name': 'video game'}, {'id': 818...
# 1205                  [{'id': 9748, 'name': 'revenge'}]
# 1206  [{'id': 14765, 'name': 'church'}, {'id': 17943...
# 1207  [{'id': 5306, 'name': 'boss'}, {'id': 12396, '...
# 1208  [{'id': 5609, 'name': 'nostalgia'}, {'id': 109...
#
# [1209 rows x 28 columns]

# %%
features = ['id', 'adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'imdb_id', 'original_language', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count']

# %%
df = df[features]
df
# Out:
#             id  adult  belongs_to_collection     budget  \
# 0     580489.0  False                    NaN  110000000
# 1     524369.0  False                    NaN          0
# 2     639721.0  False                    NaN          0
# 3     802226.0  False                    NaN          0
# 4     767504.0  False                    NaN          0
# ...        ...    ...                    ...        ...
# 1204  333339.0  False                    NaN  175000000
# 1205  464502.0  False                    NaN   20000000
# 1206  454286.0  False                    NaN          0
# 1207  412302.0  False                    NaN          0
# 1208  451204.0  False                    NaN          0
#
#                                                  genres  \
# 0     [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1                         [{'id': 80, 'name': 'Crime'}]
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 4     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...                                                 ...
# 1204  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1205                   [{'id': 53, 'name': 'Thriller'}]
# 1206                      [{'id': 18, 'name': 'Drama'}]
# 1207  [{'id': 9648, 'name': 'Mystery'}, {'id': 80, '...
# 1208                      [{'id': 18, 'name': 'Drama'}]
#
#                                         homepage     imdb_id  \
# 0                        https://www.venom.movie   tt7097896
# 1     https://www.themanysaintsofnewarkmovie.com   tt8110232
# 2     https://mgm.com/movies/the-addams-family-2  tt11125620
# 3                                                 tt13372992
# 4                                                 tt13372884
# ...                                          ...         ...
# 1204              http://readyplayeronemovie.com   tt1677720
# 1205                 https://www.acrimony.movie/   tt6063050
# 1206                                               tt6652708
# 1207              https://www.geminithefilm.com/   tt5795086
# 1208                    http://lastmoviestar.com   tt5836316
#
#      original_language                                           overview  \
# 0                   en  After finding a host body in investigative rep...
# 1                   en  Young Anthony Soprano is growing up in one of ...
# 2                   en  The Addams get tangled up in more wacky advent...
# 3                   en  In the Barrio of Oak Springs live a strong and...
# 4                   en  A teenage girl with self-esteem issues finds c...
# ...                ...                                                ...
# 1204                en  When the creator of a popular video game syste...
# 1205                en  A faithful wife takes action when it becomes c...
# 1206                en  Pastor Dave  responds to the unimaginable trag...
# 1207                en  A heinous crime tests the complex relationship...
# 1208                en  An aging screen icon gets lured into accepting...
#
#       popularity  ... release_date    revenue runtime  \
# 0        206.904  ...   2021-09-30  506863592      97
# 1         35.364  ...   2021-09-22   11620603     120
# 2         86.693  ...   2021-10-01  119815153      93
# 3         11.837  ...   2021-10-01          0      85
# 4         15.525  ...   2021-10-01          0      87
# ...          ...  ...          ...        ...     ...
# 1204      70.681  ...   2018-03-28  582890172     140
# 1205      16.712  ...   2018-03-30   34764055     120
# 1206      48.581  ...   2018-03-30    5728940     105
# 1207      12.494  ...   2017-06-14          0      93
# 1208       7.457  ...   2018-03-30          0     104
#
#                                        spoken_languages    status  \
# 0     [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 1     [{'english_name': 'Latin', 'iso_639_1': 'la', ...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 1204  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1205  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1206  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1207  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1208  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                       tagline  \
# 0
# 1                      Who made Tony Soprano?
# 2                   Unhappy to see you again.
# 3                      Are you feeling lucky?
# 4                  Find your own way to slay.
# ...                                       ...
# 1204                 A better reality awaits.
# 1205                        Hell Hath No Fury
# 1206
# 1207  It’s all there if you know how to look.
# 1208                 The best is yet to come.
#
#                                     title  video vote_average vote_count
# 0             Venom: Let There Be Carnage  False        6.880       8642
# 1               The Many Saints of Newark  False        6.475        508
# 2                     The Addams Family 2  False        7.073       1079
# 3                              Bingo Hell  False        4.895         95
# 4                          Black as Night  False        5.621        112
# ...                                   ...    ...          ...        ...
# 1204                     Ready Player One  False        7.615      13879
# 1205                             Acrimony  False        6.800        346
# 1206  God's Not Dead: A Light in Darkness  False        6.872        179
# 1207                               Gemini  False        5.500        118
# 1208                  The Last Movie Star  False        6.494         87
#
# [1209 rows x 23 columns]

# %%
df.to_csv('../content/scrap_movies.csv', sep=';', index=False)

# %% [markdown]
# # Unindo as bases de dados (Extraída por WebScraping e usando Dataset do Kaggle)

# %%
df = pd.read_csv('../content/scrap_movies.csv', sep=';')

# %%
movies_data = pd.read_csv('../content/movies_metadata.csv')
# Out:
# /var/folders/zm/3bssg1p14lj63wq1qny6y2qh0000gn/T/ipykernel_11469/3733990633.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_data = pd.read_csv('../content/movies_metadata.csv')

# %%
credits_data = pd.read_csv('../content/credits.csv')

# %%
keywords_data = pd.read_csv('../content/keywords.csv')

# %%
indexes = []

for movie_id in movies_data['id']:
  try:
    int(movie_id)
  except:
    error_index = movies_data.loc[movies_data['id']==movie_id].index.tolist()
    indexes.append(error_index[0])
    print(movie_id)
# Out:
# 1997-08-20
# 2012-09-29
# 2014-01-01

# %%
movies_data.drop(indexes, axis = 0, inplace = True)
movies_data.reset_index(drop=True, inplace=True)

# %%
movies_data['id'] = movies_data['id'].astype('int64')

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  object
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  object
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  object
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
#  14  release_date           45376 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), int64(1), object(19)
# memory usage: 8.3+ MB

# %%
credits_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
keywords_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46419 entries, 0 to 46418
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        46419 non-null  int64
#  1   keywords  46419 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 725.4+ KB

# %%
df_merged = keywords_data.merge(credits_data, how='left', on='id')

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46496 entries, 0 to 46495
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        46496 non-null  int64
#  1   keywords  46496 non-null  object
#  2   cast      46496 non-null  object
#  3   crew      46496 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.8+ MB

# %%
movies_data = movies_data.merge(df_merged, on='id', how='left')

# %%
movies_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Cheated on, mistreated and stepped on, the wom...  ...
# 4  Just when George Banks has recovered from his ...  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average  vote_count  \
# 0                    Toy Story  False           7.7      5415.0
# 1                      Jumanji  False           6.9      2413.0
# 2             Grumpier Old Men  False           6.5        92.0
# 3            Waiting to Exhale  False           6.1        34.0
# 4  Father of the Bride Part II  False           5.7       173.0
#
#                                             keywords  \
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
# [5 rows x 27 columns]

# %%
df_final = pd.concat([movies_data, df], ignore_index=True)

# %% [markdown]
# # Exportando

# %%
df_final.to_csv('../content/df_final.csv', index = False, header = True, sep=';')
