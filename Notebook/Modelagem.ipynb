# %% [markdown]
# # Importando Bibliotecas

# %%
import ast
import pickle
import requests
import warnings
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Funções

# %%
def get_movie_translation(movie_id):
    url = 'https://api.themoviedb.org/3/movie/{}/translations?api_key=c752658cbea631866744f576a4013cd1'.format(movie_id)
    data = requests.get(url)
    data = data.json()
    try:
        data = data['translations']
        for translations in data:
            if translations['iso_3166_1'] == 'BR':
                return translations['data']['title']
    except:
        return np.nan

# %%
def extract_feature(feature_dict):
  features = []
  for feature in ast.literal_eval(feature_dict):
    features.append(feature['name'])
  return features

# %%
def get_movie_director(crew):
  director = []
  for person in ast.literal_eval(crew):
    if person['job'] == 'Director':
      director.append(person['name'])
  return director

# %%
def remove_space(feature_list):
  list_without_empty = []
  for item in feature_list:
    list_without_empty.append(item.replace(' ',''))
  return list_without_empty

# %% [markdown]
# # Lendo os Dados

# %%
df=pd.read_csv('/content/movies_dataframe.csv', sep=';')
df
# Out:
#       adult                              belongs_to_collection       budget  \
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000.0
# 1     False                                                NaN   65000000.0
# 2     False  {'id': 96871, 'name': 'Father of the Bride Col...          NaN
# 3     False                                                NaN   60000000.0
# 4     False                                                NaN   58000000.0
# ...     ...                                                ...          ...
# 5670  False                                                NaN    5402000.0
# 5671  False  {'id': 52888, 'name': 'The Visitors Collection...   25868826.0
# 5672  False                                                NaN          NaN
# 5673  False                                                NaN          NaN
# 5674  False                                                NaN  110000000.0
#
#                                                  genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2                        [{'id': 35, 'name': 'Comedy'}]
# 3     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# ...                                                 ...
# 5670                     [{'id': 35, 'name': 'Comedy'}]
# 5671                     [{'id': 35, 'name': 'Comedy'}]
# 5672  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 5673                     [{'id': 35, 'name': 'Comedy'}]
# 5674  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                   homepage        id    imdb_id  \
# 0     http://toystory.disney.com/toy-story     862.0  tt0114709
# 1                                      NaN    8844.0  tt0113497
# 2                                      NaN   11862.0  tt0113041
# 3                                      NaN     949.0  tt0113277
# 4                                      NaN   11860.0  tt0114319
# ...                                    ...       ...        ...
# 5670                                   NaN  277839.0  tt4531694
# 5671                                   NaN  248705.0  tt2441982
# 5672                                   NaN  455661.0  tt6969946
# 5673                                   NaN   14008.0  tt0294425
# 5674               https://www.venom.movie  580489.0  tt7097896
#
#      original_language                original_title  \
# 0                   en                     Toy Story
# 1                   en                       Jumanji
# 2                   en   Father of the Bride Part II
# 3                   en                          Heat
# 4                   en                       Sabrina
# ...                ...                           ...
# 5670                fr                       Pattaya
# 5671                fr  Les Visiteurs: La Révolution
# 5672                en                In a Heartbeat
# 5673                en                   Cadet Kelly
# 5674                en                           NaN
#
#                                                overview  ...  \
# 0     Led by Woody, Andy's toys live happily in his ...  ...
# 1     When siblings Judy and Peter discover an encha...  ...
# 2     Just when George Banks has recovered from his ...  ...
# 3     Obsessive master thief, Neil McCauley leads a ...  ...
# 4     An ugly duckling having undergone a remarkable...  ...
# ...                                                 ...  ...
# 5670  Franky and Krimo dream of leaving the grey gri...  ...
# 5671  Stuck in the corridors of time, Godefroy de Mo...  ...
# 5672  A closeted boy runs the risk of being outed by...  ...
# 5673  Hyperactive teenager Kelly is enrolled into a ...  ...
# 5674  After finding a host body in investigative rep...  ...
#
#                                                title  video vote_average  \
# 0                                          Toy Story  False         7.70
# 1                                            Jumanji  False         6.90
# 2                        Father of the Bride Part II  False         5.70
# 3                                               Heat  False         7.70
# 4                                            Sabrina  False         6.20
# ...                                              ...    ...          ...
# 5670  Good Guys Go to Heaven, Bad Guys Go to Pattaya  False         5.30
# 5671                      The Visitors: Bastille Day  False         4.00
# 5672                                  In a Heartbeat  False         8.30
# 5673                                     Cadet Kelly  False         5.20
# 5674                     Venom: Let There Be Carnage  False         6.88
#
#      vote_count                                           keywords  \
# 0          5415  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1          2413  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2           173  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# 3          1886  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 4           141  [{'id': 90, 'name': 'paris'}, {'id': 380, 'nam...
# ...         ...                                                ...
# 5670        153                                                 []
# 5671        167  [{'id': 2652, 'name': 'nazis'}, {'id': 3098, '...
# 5672        146  [{'id': 9673, 'name': 'love'}, {'id': 13130, '...
# 5673        145        [{'id': 171803, 'name': 'military school'}]
# 5674       8642                                                NaN
#
#                                                    cast  \
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1     [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2     [{'cast_id': 1, 'character': 'George Banks', '...
# 3     [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4     [{'cast_id': 1, 'character': 'Linus Larrabee',...
# ...                                                 ...
# 5670  [{'cast_id': 0, 'character': 'Reaz', 'credit_i...
# 5671  [{'cast_id': 2, 'character': 'Le comte Godefro...
# 5672                                                 []
# 5673  [{'cast_id': 1, 'character': 'Kelly Collins', ...
# 5674                                                NaN
#
#                                                    crew     return    year  \
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...  12.451801  1995.0
# 1     [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   4.043035  1995.0
# 2     [{'credit_id': '52fe44959251416c75039ed7', 'de...        NaN  1995.0
# 3     [{'credit_id': '52fe4292c3a36847f802916d', 'de...   3.123947  1995.0
# 4     [{'credit_id': '52fe44959251416c75039da9', 'de...   0.000000  1995.0
# ...                                                 ...        ...     ...
# 5670  [{'credit_id': '53a5be030e0a261449001835', 'de...   0.000000  2016.0
# 5671  [{'credit_id': '52fe4f37c3a36847f82c5efb', 'de...   0.000000  2016.0
# 5672  [{'credit_id': '5981a15c92514151e0011b51', 'de...        NaN  2017.0
# 5673  [{'credit_id': '52fe45c29251416c75061803', 'de...        NaN  2002.0
# 5674                                                NaN   4.607851  2021.0
#
#      month
# 0       10
# 1       12
# 2        2
# 3       12
# 4       12
# ...    ...
# 5670     2
# 5671     3
# 5672     6
# 5673     3
# 5674     9
#
# [5675 rows x 30 columns]

# %%
df['titulo'] = df['id'].apply(get_movie_translation)
df
# Out:
#       adult                              belongs_to_collection       budget  \
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000.0
# 1     False                                                NaN   65000000.0
# 2     False  {'id': 96871, 'name': 'Father of the Bride Col...          NaN
# 3     False                                                NaN   60000000.0
# 4     False                                                NaN   58000000.0
# ...     ...                                                ...          ...
# 5670  False                                                NaN    5402000.0
# 5671  False  {'id': 52888, 'name': 'The Visitors Collection...   25868826.0
# 5672  False                                                NaN          NaN
# 5673  False                                                NaN          NaN
# 5674  False                                                NaN  110000000.0
#
#                                                  genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2                        [{'id': 35, 'name': 'Comedy'}]
# 3     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# ...                                                 ...
# 5670                     [{'id': 35, 'name': 'Comedy'}]
# 5671                     [{'id': 35, 'name': 'Comedy'}]
# 5672  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 5673                     [{'id': 35, 'name': 'Comedy'}]
# 5674  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                   homepage        id    imdb_id  \
# 0     http://toystory.disney.com/toy-story     862.0  tt0114709
# 1                                      NaN    8844.0  tt0113497
# 2                                      NaN   11862.0  tt0113041
# 3                                      NaN     949.0  tt0113277
# 4                                      NaN   11860.0  tt0114319
# ...                                    ...       ...        ...
# 5670                                   NaN  277839.0  tt4531694
# 5671                                   NaN  248705.0  tt2441982
# 5672                                   NaN  455661.0  tt6969946
# 5673                                   NaN   14008.0  tt0294425
# 5674               https://www.venom.movie  580489.0  tt7097896
#
#      original_language                original_title  \
# 0                   en                     Toy Story
# 1                   en                       Jumanji
# 2                   en   Father of the Bride Part II
# 3                   en                          Heat
# 4                   en                       Sabrina
# ...                ...                           ...
# 5670                fr                       Pattaya
# 5671                fr  Les Visiteurs: La Révolution
# 5672                en                In a Heartbeat
# 5673                en                   Cadet Kelly
# 5674                en                           NaN
#
#                                                overview  ...  video  \
# 0     Led by Woody, Andy's toys live happily in his ...  ...  False
# 1     When siblings Judy and Peter discover an encha...  ...  False
# 2     Just when George Banks has recovered from his ...  ...  False
# 3     Obsessive master thief, Neil McCauley leads a ...  ...  False
# 4     An ugly duckling having undergone a remarkable...  ...  False
# ...                                                 ...  ...    ...
# 5670  Franky and Krimo dream of leaving the grey gri...  ...  False
# 5671  Stuck in the corridors of time, Godefroy de Mo...  ...  False
# 5672  A closeted boy runs the risk of being outed by...  ...  False
# 5673  Hyperactive teenager Kelly is enrolled into a ...  ...  False
# 5674  After finding a host body in investigative rep...  ...  False
#
#      vote_average vote_count  \
# 0            7.70       5415
# 1            6.90       2413
# 2            5.70        173
# 3            7.70       1886
# 4            6.20        141
# ...           ...        ...
# 5670         5.30        153
# 5671         4.00        167
# 5672         8.30        146
# 5673         5.20        145
# 5674         6.88       8642
#
#                                                keywords  \
# 0     [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2     [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# 3     [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 4     [{'id': 90, 'name': 'paris'}, {'id': 380, 'nam...
# ...                                                 ...
# 5670                                                 []
# 5671  [{'id': 2652, 'name': 'nazis'}, {'id': 3098, '...
# 5672  [{'id': 9673, 'name': 'love'}, {'id': 13130, '...
# 5673        [{'id': 171803, 'name': 'military school'}]
# 5674                                                NaN
#
#                                                    cast  \
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1     [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2     [{'cast_id': 1, 'character': 'George Banks', '...
# 3     [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4     [{'cast_id': 1, 'character': 'Linus Larrabee',...
# ...                                                 ...
# 5670  [{'cast_id': 0, 'character': 'Reaz', 'credit_i...
# 5671  [{'cast_id': 2, 'character': 'Le comte Godefro...
# 5672                                                 []
# 5673  [{'cast_id': 1, 'character': 'Kelly Collins', ...
# 5674                                                NaN
#
#                                                    crew     return    year  \
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...  12.451801  1995.0
# 1     [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   4.043035  1995.0
# 2     [{'credit_id': '52fe44959251416c75039ed7', 'de...        NaN  1995.0
# 3     [{'credit_id': '52fe4292c3a36847f802916d', 'de...   3.123947  1995.0
# 4     [{'credit_id': '52fe44959251416c75039da9', 'de...   0.000000  1995.0
# ...                                                 ...        ...     ...
# 5670  [{'credit_id': '53a5be030e0a261449001835', 'de...   0.000000  2016.0
# 5671  [{'credit_id': '52fe4f37c3a36847f82c5efb', 'de...   0.000000  2016.0
# 5672  [{'credit_id': '5981a15c92514151e0011b51', 'de...        NaN  2017.0
# 5673  [{'credit_id': '52fe45c29251416c75061803', 'de...        NaN  2002.0
# 5674                                                NaN   4.607851  2021.0
#
#      month                            titulo
# 0       10  Toy Story: Um Mundo de Aventuras
# 1       12
# 2        2                 O Pai da Noiva II
# 3       12                  Fogo Contra Fogo
# 4       12
# ...    ...                               ...
# 5670     2                              None
# 5671     3        The Visitors: Bastille Day
# 5672     6               Num piscar de Olhos
# 5673     3                      Cadete Kelly
# 5674     9       Venom: Tempo de Carnificina
#
# [5675 rows x 31 columns]

# %% [markdown]
# # Content Filtering

# %%
df_movies = df[['id', 'title', 'titulo', 'genres', 'overview', 'keywords', 'cast', 'crew']]
df_movies
# Out:
#             id                                           title  \
# 0        862.0                                       Toy Story
# 1       8844.0                                         Jumanji
# 2      11862.0                     Father of the Bride Part II
# 3        949.0                                            Heat
# 4      11860.0                                         Sabrina
# ...        ...                                             ...
# 5670  277839.0  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671  248705.0                      The Visitors: Bastille Day
# 5672  455661.0                                  In a Heartbeat
# 5673   14008.0                                     Cadet Kelly
# 5674  580489.0                     Venom: Let There Be Carnage
#
#                                 titulo  \
# 0     Toy Story: Um Mundo de Aventuras
# 1
# 2                    O Pai da Noiva II
# 3                     Fogo Contra Fogo
# 4
# ...                                ...
# 5670                              None
# 5671        The Visitors: Bastille Day
# 5672               Num piscar de Olhos
# 5673                      Cadete Kelly
# 5674       Venom: Tempo de Carnificina
#
#                                                  genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2                        [{'id': 35, 'name': 'Comedy'}]
# 3     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# ...                                                 ...
# 5670                     [{'id': 35, 'name': 'Comedy'}]
# 5671                     [{'id': 35, 'name': 'Comedy'}]
# 5672  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 5673                     [{'id': 35, 'name': 'Comedy'}]
# 5674  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                                overview  \
# 0     Led by Woody, Andy's toys live happily in his ...
# 1     When siblings Judy and Peter discover an encha...
# 2     Just when George Banks has recovered from his ...
# 3     Obsessive master thief, Neil McCauley leads a ...
# 4     An ugly duckling having undergone a remarkable...
# ...                                                 ...
# 5670  Franky and Krimo dream of leaving the grey gri...
# 5671  Stuck in the corridors of time, Godefroy de Mo...
# 5672  A closeted boy runs the risk of being outed by...
# 5673  Hyperactive teenager Kelly is enrolled into a ...
# 5674  After finding a host body in investigative rep...
#
#                                                keywords  \
# 0     [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2     [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# 3     [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 4     [{'id': 90, 'name': 'paris'}, {'id': 380, 'nam...
# ...                                                 ...
# 5670                                                 []
# 5671  [{'id': 2652, 'name': 'nazis'}, {'id': 3098, '...
# 5672  [{'id': 9673, 'name': 'love'}, {'id': 13130, '...
# 5673        [{'id': 171803, 'name': 'military school'}]
# 5674                                                NaN
#
#                                                    cast  \
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1     [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2     [{'cast_id': 1, 'character': 'George Banks', '...
# 3     [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4     [{'cast_id': 1, 'character': 'Linus Larrabee',...
# ...                                                 ...
# 5670  [{'cast_id': 0, 'character': 'Reaz', 'credit_i...
# 5671  [{'cast_id': 2, 'character': 'Le comte Godefro...
# 5672                                                 []
# 5673  [{'cast_id': 1, 'character': 'Kelly Collins', ...
# 5674                                                NaN
#
#                                                    crew
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1     [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2     [{'credit_id': '52fe44959251416c75039ed7', 'de...
# 3     [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 4     [{'credit_id': '52fe44959251416c75039da9', 'de...
# ...                                                 ...
# 5670  [{'credit_id': '53a5be030e0a261449001835', 'de...
# 5671  [{'credit_id': '52fe4f37c3a36847f82c5efb', 'de...
# 5672  [{'credit_id': '5981a15c92514151e0011b51', 'de...
# 5673  [{'credit_id': '52fe45c29251416c75061803', 'de...
# 5674                                                NaN
#
# [5675 rows x 8 columns]

# %%
df_movies['titulo'] = df_movies['titulo'].replace('', np.nan)
df_movies['titulo'] = df_movies['titulo'].replace([None], np.nan)
df_movies
# Out:
#             id                                           title  \
# 0        862.0                                       Toy Story
# 1       8844.0                                         Jumanji
# 2      11862.0                     Father of the Bride Part II
# 3        949.0                                            Heat
# 4      11860.0                                         Sabrina
# ...        ...                                             ...
# 5670  277839.0  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671  248705.0                      The Visitors: Bastille Day
# 5672  455661.0                                  In a Heartbeat
# 5673   14008.0                                     Cadet Kelly
# 5674  580489.0                     Venom: Let There Be Carnage
#
#                                 titulo  \
# 0     Toy Story: Um Mundo de Aventuras
# 1                                  NaN
# 2                    O Pai da Noiva II
# 3                     Fogo Contra Fogo
# 4                                  NaN
# ...                                ...
# 5670                               NaN
# 5671        The Visitors: Bastille Day
# 5672               Num piscar de Olhos
# 5673                      Cadete Kelly
# 5674       Venom: Tempo de Carnificina
#
#                                                  genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2                        [{'id': 35, 'name': 'Comedy'}]
# 3     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# ...                                                 ...
# 5670                     [{'id': 35, 'name': 'Comedy'}]
# 5671                     [{'id': 35, 'name': 'Comedy'}]
# 5672  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 5673                     [{'id': 35, 'name': 'Comedy'}]
# 5674  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                                overview  \
# 0     Led by Woody, Andy's toys live happily in his ...
# 1     When siblings Judy and Peter discover an encha...
# 2     Just when George Banks has recovered from his ...
# 3     Obsessive master thief, Neil McCauley leads a ...
# 4     An ugly duckling having undergone a remarkable...
# ...                                                 ...
# 5670  Franky and Krimo dream of leaving the grey gri...
# 5671  Stuck in the corridors of time, Godefroy de Mo...
# 5672  A closeted boy runs the risk of being outed by...
# 5673  Hyperactive teenager Kelly is enrolled into a ...
# 5674  After finding a host body in investigative rep...
#
#                                                keywords  \
# 0     [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2     [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# 3     [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 4     [{'id': 90, 'name': 'paris'}, {'id': 380, 'nam...
# ...                                                 ...
# 5670                                                 []
# 5671  [{'id': 2652, 'name': 'nazis'}, {'id': 3098, '...
# 5672  [{'id': 9673, 'name': 'love'}, {'id': 13130, '...
# 5673        [{'id': 171803, 'name': 'military school'}]
# 5674                                                NaN
#
#                                                    cast  \
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1     [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2     [{'cast_id': 1, 'character': 'George Banks', '...
# 3     [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4     [{'cast_id': 1, 'character': 'Linus Larrabee',...
# ...                                                 ...
# 5670  [{'cast_id': 0, 'character': 'Reaz', 'credit_i...
# 5671  [{'cast_id': 2, 'character': 'Le comte Godefro...
# 5672                                                 []
# 5673  [{'cast_id': 1, 'character': 'Kelly Collins', ...
# 5674                                                NaN
#
#                                                    crew
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1     [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2     [{'credit_id': '52fe44959251416c75039ed7', 'de...
# 3     [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 4     [{'credit_id': '52fe44959251416c75039da9', 'de...
# ...                                                 ...
# 5670  [{'credit_id': '53a5be030e0a261449001835', 'de...
# 5671  [{'credit_id': '52fe4f37c3a36847f82c5efb', 'de...
# 5672  [{'credit_id': '5981a15c92514151e0011b51', 'de...
# 5673  [{'credit_id': '52fe45c29251416c75061803', 'de...
# 5674                                                NaN
#
# [5675 rows x 8 columns]

# %%
df_movies['titulo'] = df_movies['titulo'].fillna(df_movies['title'])
df_movies
# Out:
#             id                                           title  \
# 0        862.0                                       Toy Story
# 1       8844.0                                         Jumanji
# 2      11862.0                     Father of the Bride Part II
# 3        949.0                                            Heat
# 4      11860.0                                         Sabrina
# ...        ...                                             ...
# 5670  277839.0  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671  248705.0                      The Visitors: Bastille Day
# 5672  455661.0                                  In a Heartbeat
# 5673   14008.0                                     Cadet Kelly
# 5674  580489.0                     Venom: Let There Be Carnage
#
#                                               titulo  \
# 0                   Toy Story: Um Mundo de Aventuras
# 1                                            Jumanji
# 2                                  O Pai da Noiva II
# 3                                   Fogo Contra Fogo
# 4                                            Sabrina
# ...                                              ...
# 5670  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671                      The Visitors: Bastille Day
# 5672                             Num piscar de Olhos
# 5673                                    Cadete Kelly
# 5674                     Venom: Tempo de Carnificina
#
#                                                  genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2                        [{'id': 35, 'name': 'Comedy'}]
# 3     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# ...                                                 ...
# 5670                     [{'id': 35, 'name': 'Comedy'}]
# 5671                     [{'id': 35, 'name': 'Comedy'}]
# 5672  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 5673                     [{'id': 35, 'name': 'Comedy'}]
# 5674  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                                overview  \
# 0     Led by Woody, Andy's toys live happily in his ...
# 1     When siblings Judy and Peter discover an encha...
# 2     Just when George Banks has recovered from his ...
# 3     Obsessive master thief, Neil McCauley leads a ...
# 4     An ugly duckling having undergone a remarkable...
# ...                                                 ...
# 5670  Franky and Krimo dream of leaving the grey gri...
# 5671  Stuck in the corridors of time, Godefroy de Mo...
# 5672  A closeted boy runs the risk of being outed by...
# 5673  Hyperactive teenager Kelly is enrolled into a ...
# 5674  After finding a host body in investigative rep...
#
#                                                keywords  \
# 0     [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2     [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# 3     [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 4     [{'id': 90, 'name': 'paris'}, {'id': 380, 'nam...
# ...                                                 ...
# 5670                                                 []
# 5671  [{'id': 2652, 'name': 'nazis'}, {'id': 3098, '...
# 5672  [{'id': 9673, 'name': 'love'}, {'id': 13130, '...
# 5673        [{'id': 171803, 'name': 'military school'}]
# 5674                                                NaN
#
#                                                    cast  \
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1     [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2     [{'cast_id': 1, 'character': 'George Banks', '...
# 3     [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4     [{'cast_id': 1, 'character': 'Linus Larrabee',...
# ...                                                 ...
# 5670  [{'cast_id': 0, 'character': 'Reaz', 'credit_i...
# 5671  [{'cast_id': 2, 'character': 'Le comte Godefro...
# 5672                                                 []
# 5673  [{'cast_id': 1, 'character': 'Kelly Collins', ...
# 5674                                                NaN
#
#                                                    crew
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1     [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2     [{'credit_id': '52fe44959251416c75039ed7', 'de...
# 3     [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 4     [{'credit_id': '52fe44959251416c75039da9', 'de...
# ...                                                 ...
# 5670  [{'credit_id': '53a5be030e0a261449001835', 'de...
# 5671  [{'credit_id': '52fe4f37c3a36847f82c5efb', 'de...
# 5672  [{'credit_id': '5981a15c92514151e0011b51', 'de...
# 5673  [{'credit_id': '52fe45c29251416c75061803', 'de...
# 5674                                                NaN
#
# [5675 rows x 8 columns]

# %%
df_movies.isnull().sum()
# Out:
# id           0
# title        0
# titulo       0
# genres       0
# overview    11
# keywords     1
# cast         1
# crew         1
# dtype: int64

# %%
df_movies.dropna(inplace=True)

# %%
df_movies.isnull().sum()
# Out:
# id          0
# title       0
# titulo      0
# genres      0
# overview    0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
df_movies['genres'] = df_movies['genres'].apply(extract_feature)
df_movies['keywords'] = df_movies['keywords'].apply(extract_feature)
df_movies['cast'] = df_movies['cast'].apply(extract_feature)

# %%
df_movies['crew'] = df_movies['crew'].apply(get_movie_director)
df_movies
# Out:
#             id                                           title  \
# 0        862.0                                       Toy Story
# 1       8844.0                                         Jumanji
# 2      11862.0                     Father of the Bride Part II
# 3        949.0                                            Heat
# 4      11860.0                                         Sabrina
# ...        ...                                             ...
# 5669  417320.0                                   Descendants 2
# 5670  277839.0  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671  248705.0                      The Visitors: Bastille Day
# 5672  455661.0                                  In a Heartbeat
# 5673   14008.0                                     Cadet Kelly
#
#                                               titulo  \
# 0                   Toy Story: Um Mundo de Aventuras
# 1                                            Jumanji
# 2                                  O Pai da Noiva II
# 3                                   Fogo Contra Fogo
# 4                                            Sabrina
# ...                                              ...
# 5669                                  Descendentes 2
# 5670  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671                      The Visitors: Bastille Day
# 5672                             Num piscar de Olhos
# 5673                                    Cadete Kelly
#
#                                                  genres  \
# 0                           [Animation, Comedy, Family]
# 1                          [Adventure, Fantasy, Family]
# 2                                              [Comedy]
# 3                      [Action, Crime, Drama, Thriller]
# 4                                     [Comedy, Romance]
# ...                                                 ...
# 5669  [TV Movie, Family, Action, Comedy, Music, Adve...
# 5670                                           [Comedy]
# 5671                                           [Comedy]
# 5672               [Family, Animation, Romance, Comedy]
# 5673                                           [Comedy]
#
#                                                overview  \
# 0     Led by Woody, Andy's toys live happily in his ...
# 1     When siblings Judy and Peter discover an encha...
# 2     Just when George Banks has recovered from his ...
# 3     Obsessive master thief, Neil McCauley leads a ...
# 4     An ugly duckling having undergone a remarkable...
# ...                                                 ...
# 5669  When the pressure to be royal becomes too much...
# 5670  Franky and Krimo dream of leaving the grey gri...
# 5671  Stuck in the corridors of time, Godefroy de Mo...
# 5672  A closeted boy runs the risk of being outed by...
# 5673  Hyperactive teenager Kelly is enrolled into a ...
#
#                                                keywords  \
# 0     [jealousy, toy, boy, friendship, friends, riva...
# 1     [board game, disappearance, based on children'...
# 2     [baby, midlife crisis, confidence, aging, daug...
# 3     [robbery, detective, bank, obsession, chase, s...
# 4     [paris, brother brother relationship, chauffeu...
# ...                                                 ...
# 5669  [fairy tale, villain, musical, teen movie, tee...
# 5670                                                 []
# 5671          [nazis, castle, time travel, robespierre]
# 5672                      [love, teenager, lgbt, short]
# 5673                                  [military school]
#
#                                                    cast  \
# 0     [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1     [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2     [Steve Martin, Diane Keaton, Martin Short, Kim...
# 3     [Al Pacino, Robert De Niro, Val Kilmer, Jon Vo...
# 4     [Harrison Ford, Julia Ormond, Greg Kinnear, An...
# ...                                                 ...
# 5669  [Dove Cameron, Sofia Carson, Cameron Boyce, Bo...
# 5670  [Ramzy Bedia, Malik Bentalha, Franck Gastambid...
# 5671  [Jean Reno, Christian Clavier, Franck Dubosc, ...
# 5672                                                 []
# 5673  [Hilary Duff, Christy Carlson Romano, Gary Col...
#
#                              crew
# 0                 [John Lasseter]
# 1                  [Joe Johnston]
# 2                 [Charles Shyer]
# 3                  [Michael Mann]
# 4                [Sydney Pollack]
# ...                           ...
# 5669               [Kenny Ortega]
# 5670          [Franck Gastambide]
# 5671           [Jean-Marie Poiré]
# 5672  [Beth David, Esteban Bravo]
# 5673                 [Larry Shaw]
#
# [5663 rows x 8 columns]

# %%
df_movies['cast'] = df_movies['cast'].apply(remove_space)
df_movies['crew'] = df_movies['crew'].apply(remove_space)
df_movies['genres'] = df_movies['genres'].apply(remove_space)
df_movies['keywords'] = df_movies['keywords'].apply(remove_space)
df_movies
# Out:
#             id                                           title  \
# 0        862.0                                       Toy Story
# 1       8844.0                                         Jumanji
# 2      11862.0                     Father of the Bride Part II
# 3        949.0                                            Heat
# 4      11860.0                                         Sabrina
# ...        ...                                             ...
# 5669  417320.0                                   Descendants 2
# 5670  277839.0  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671  248705.0                      The Visitors: Bastille Day
# 5672  455661.0                                  In a Heartbeat
# 5673   14008.0                                     Cadet Kelly
#
#                                               titulo  \
# 0                   Toy Story: Um Mundo de Aventuras
# 1                                            Jumanji
# 2                                  O Pai da Noiva II
# 3                                   Fogo Contra Fogo
# 4                                            Sabrina
# ...                                              ...
# 5669                                  Descendentes 2
# 5670  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671                      The Visitors: Bastille Day
# 5672                             Num piscar de Olhos
# 5673                                    Cadete Kelly
#
#                                                  genres  \
# 0                           [Animation, Comedy, Family]
# 1                          [Adventure, Fantasy, Family]
# 2                                              [Comedy]
# 3                      [Action, Crime, Drama, Thriller]
# 4                                     [Comedy, Romance]
# ...                                                 ...
# 5669  [TVMovie, Family, Action, Comedy, Music, Adven...
# 5670                                           [Comedy]
# 5671                                           [Comedy]
# 5672               [Family, Animation, Romance, Comedy]
# 5673                                           [Comedy]
#
#                                                overview  \
# 0     Led by Woody, Andy's toys live happily in his ...
# 1     When siblings Judy and Peter discover an encha...
# 2     Just when George Banks has recovered from his ...
# 3     Obsessive master thief, Neil McCauley leads a ...
# 4     An ugly duckling having undergone a remarkable...
# ...                                                 ...
# 5669  When the pressure to be royal becomes too much...
# 5670  Franky and Krimo dream of leaving the grey gri...
# 5671  Stuck in the corridors of time, Godefroy de Mo...
# 5672  A closeted boy runs the risk of being outed by...
# 5673  Hyperactive teenager Kelly is enrolled into a ...
#
#                                                keywords  \
# 0     [jealousy, toy, boy, friendship, friends, riva...
# 1     [boardgame, disappearance, basedonchildren'sbo...
# 2     [baby, midlifecrisis, confidence, aging, daugh...
# 3     [robbery, detective, bank, obsession, chase, s...
# 4     [paris, brotherbrotherrelationship, chauffeur,...
# ...                                                 ...
# 5669  [fairytale, villain, musical, teenmovie, teena...
# 5670                                                 []
# 5671           [nazis, castle, timetravel, robespierre]
# 5672                      [love, teenager, lgbt, short]
# 5673                                   [militaryschool]
#
#                                                    cast  \
# 0     [TomHanks, TimAllen, DonRickles, JimVarney, Wa...
# 1     [RobinWilliams, JonathanHyde, KirstenDunst, Br...
# 2     [SteveMartin, DianeKeaton, MartinShort, Kimber...
# 3     [AlPacino, RobertDeNiro, ValKilmer, JonVoight,...
# 4     [HarrisonFord, JuliaOrmond, GregKinnear, Angie...
# ...                                                 ...
# 5669  [DoveCameron, SofiaCarson, CameronBoyce, Boobo...
# 5670  [RamzyBedia, MalikBentalha, FranckGastambide, ...
# 5671  [JeanReno, ChristianClavier, FranckDubosc, Kar...
# 5672                                                 []
# 5673  [HilaryDuff, ChristyCarlsonRomano, GaryCole, S...
#
#                            crew
# 0                [JohnLasseter]
# 1                 [JoeJohnston]
# 2                [CharlesShyer]
# 3                 [MichaelMann]
# 4               [SydneyPollack]
# ...                         ...
# 5669              [KennyOrtega]
# 5670         [FranckGastambide]
# 5671          [Jean-MariePoiré]
# 5672  [BethDavid, EstebanBravo]
# 5673                [LarryShaw]
#
# [5663 rows x 8 columns]

# %%
df_movies['overview'] = df_movies['overview'].apply(lambda x: x.split())
df_movies
# Out:
#             id                                           title  \
# 0        862.0                                       Toy Story
# 1       8844.0                                         Jumanji
# 2      11862.0                     Father of the Bride Part II
# 3        949.0                                            Heat
# 4      11860.0                                         Sabrina
# ...        ...                                             ...
# 5669  417320.0                                   Descendants 2
# 5670  277839.0  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671  248705.0                      The Visitors: Bastille Day
# 5672  455661.0                                  In a Heartbeat
# 5673   14008.0                                     Cadet Kelly
#
#                                               titulo  \
# 0                   Toy Story: Um Mundo de Aventuras
# 1                                            Jumanji
# 2                                  O Pai da Noiva II
# 3                                   Fogo Contra Fogo
# 4                                            Sabrina
# ...                                              ...
# 5669                                  Descendentes 2
# 5670  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671                      The Visitors: Bastille Day
# 5672                             Num piscar de Olhos
# 5673                                    Cadete Kelly
#
#                                                  genres  \
# 0                           [Animation, Comedy, Family]
# 1                          [Adventure, Fantasy, Family]
# 2                                              [Comedy]
# 3                      [Action, Crime, Drama, Thriller]
# 4                                     [Comedy, Romance]
# ...                                                 ...
# 5669  [TVMovie, Family, Action, Comedy, Music, Adven...
# 5670                                           [Comedy]
# 5671                                           [Comedy]
# 5672               [Family, Animation, Romance, Comedy]
# 5673                                           [Comedy]
#
#                                                overview  \
# 0     [Led, by, Woody,, Andy's, toys, live, happily,...
# 1     [When, siblings, Judy, and, Peter, discover, a...
# 2     [Just, when, George, Banks, has, recovered, fr...
# 3     [Obsessive, master, thief,, Neil, McCauley, le...
# 4     [An, ugly, duckling, having, undergone, a, rem...
# ...                                                 ...
# 5669  [When, the, pressure, to, be, royal, becomes, ...
# 5670  [Franky, and, Krimo, dream, of, leaving, the, ...
# 5671  [Stuck, in, the, corridors, of, time,, Godefro...
# 5672  [A, closeted, boy, runs, the, risk, of, being,...
# 5673  [Hyperactive, teenager, Kelly, is, enrolled, i...
#
#                                                keywords  \
# 0     [jealousy, toy, boy, friendship, friends, riva...
# 1     [boardgame, disappearance, basedonchildren'sbo...
# 2     [baby, midlifecrisis, confidence, aging, daugh...
# 3     [robbery, detective, bank, obsession, chase, s...
# 4     [paris, brotherbrotherrelationship, chauffeur,...
# ...                                                 ...
# 5669  [fairytale, villain, musical, teenmovie, teena...
# 5670                                                 []
# 5671           [nazis, castle, timetravel, robespierre]
# 5672                      [love, teenager, lgbt, short]
# 5673                                   [militaryschool]
#
#                                                    cast  \
# 0     [TomHanks, TimAllen, DonRickles, JimVarney, Wa...
# 1     [RobinWilliams, JonathanHyde, KirstenDunst, Br...
# 2     [SteveMartin, DianeKeaton, MartinShort, Kimber...
# 3     [AlPacino, RobertDeNiro, ValKilmer, JonVoight,...
# 4     [HarrisonFord, JuliaOrmond, GregKinnear, Angie...
# ...                                                 ...
# 5669  [DoveCameron, SofiaCarson, CameronBoyce, Boobo...
# 5670  [RamzyBedia, MalikBentalha, FranckGastambide, ...
# 5671  [JeanReno, ChristianClavier, FranckDubosc, Kar...
# 5672                                                 []
# 5673  [HilaryDuff, ChristyCarlsonRomano, GaryCole, S...
#
#                            crew
# 0                [JohnLasseter]
# 1                 [JoeJohnston]
# 2                [CharlesShyer]
# 3                 [MichaelMann]
# 4               [SydneyPollack]
# ...                         ...
# 5669              [KennyOrtega]
# 5670         [FranckGastambide]
# 5671          [Jean-MariePoiré]
# 5672  [BethDavid, EstebanBravo]
# 5673                [LarryShaw]
#
# [5663 rows x 8 columns]

# %%
df_movies['tags'] = df_movies['genres'] + df_movies['overview'] +  df_movies['keywords'] +  df_movies['cast'] +  df_movies['crew']
df_movies
# Out:
#             id                                           title  \
# 0        862.0                                       Toy Story
# 1       8844.0                                         Jumanji
# 2      11862.0                     Father of the Bride Part II
# 3        949.0                                            Heat
# 4      11860.0                                         Sabrina
# ...        ...                                             ...
# 5669  417320.0                                   Descendants 2
# 5670  277839.0  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671  248705.0                      The Visitors: Bastille Day
# 5672  455661.0                                  In a Heartbeat
# 5673   14008.0                                     Cadet Kelly
#
#                                               titulo  \
# 0                   Toy Story: Um Mundo de Aventuras
# 1                                            Jumanji
# 2                                  O Pai da Noiva II
# 3                                   Fogo Contra Fogo
# 4                                            Sabrina
# ...                                              ...
# 5669                                  Descendentes 2
# 5670  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671                      The Visitors: Bastille Day
# 5672                             Num piscar de Olhos
# 5673                                    Cadete Kelly
#
#                                                  genres  \
# 0                           [Animation, Comedy, Family]
# 1                          [Adventure, Fantasy, Family]
# 2                                              [Comedy]
# 3                      [Action, Crime, Drama, Thriller]
# 4                                     [Comedy, Romance]
# ...                                                 ...
# 5669  [TVMovie, Family, Action, Comedy, Music, Adven...
# 5670                                           [Comedy]
# 5671                                           [Comedy]
# 5672               [Family, Animation, Romance, Comedy]
# 5673                                           [Comedy]
#
#                                                overview  \
# 0     [Led, by, Woody,, Andy's, toys, live, happily,...
# 1     [When, siblings, Judy, and, Peter, discover, a...
# 2     [Just, when, George, Banks, has, recovered, fr...
# 3     [Obsessive, master, thief,, Neil, McCauley, le...
# 4     [An, ugly, duckling, having, undergone, a, rem...
# ...                                                 ...
# 5669  [When, the, pressure, to, be, royal, becomes, ...
# 5670  [Franky, and, Krimo, dream, of, leaving, the, ...
# 5671  [Stuck, in, the, corridors, of, time,, Godefro...
# 5672  [A, closeted, boy, runs, the, risk, of, being,...
# 5673  [Hyperactive, teenager, Kelly, is, enrolled, i...
#
#                                                keywords  \
# 0     [jealousy, toy, boy, friendship, friends, riva...
# 1     [boardgame, disappearance, basedonchildren'sbo...
# 2     [baby, midlifecrisis, confidence, aging, daugh...
# 3     [robbery, detective, bank, obsession, chase, s...
# 4     [paris, brotherbrotherrelationship, chauffeur,...
# ...                                                 ...
# 5669  [fairytale, villain, musical, teenmovie, teena...
# 5670                                                 []
# 5671           [nazis, castle, timetravel, robespierre]
# 5672                      [love, teenager, lgbt, short]
# 5673                                   [militaryschool]
#
#                                                    cast  \
# 0     [TomHanks, TimAllen, DonRickles, JimVarney, Wa...
# 1     [RobinWilliams, JonathanHyde, KirstenDunst, Br...
# 2     [SteveMartin, DianeKeaton, MartinShort, Kimber...
# 3     [AlPacino, RobertDeNiro, ValKilmer, JonVoight,...
# 4     [HarrisonFord, JuliaOrmond, GregKinnear, Angie...
# ...                                                 ...
# 5669  [DoveCameron, SofiaCarson, CameronBoyce, Boobo...
# 5670  [RamzyBedia, MalikBentalha, FranckGastambide, ...
# 5671  [JeanReno, ChristianClavier, FranckDubosc, Kar...
# 5672                                                 []
# 5673  [HilaryDuff, ChristyCarlsonRomano, GaryCole, S...
#
#                            crew  \
# 0                [JohnLasseter]
# 1                 [JoeJohnston]
# 2                [CharlesShyer]
# 3                 [MichaelMann]
# 4               [SydneyPollack]
# ...                         ...
# 5669              [KennyOrtega]
# 5670         [FranckGastambide]
# 5671          [Jean-MariePoiré]
# 5672  [BethDavid, EstebanBravo]
# 5673                [LarryShaw]
#
#                                                    tags
# 0     [Animation, Comedy, Family, Led, by, Woody,, A...
# 1     [Adventure, Fantasy, Family, When, siblings, J...
# 2     [Comedy, Just, when, George, Banks, has, recov...
# 3     [Action, Crime, Drama, Thriller, Obsessive, ma...
# 4     [Comedy, Romance, An, ugly, duckling, having, ...
# ...                                                 ...
# 5669  [TVMovie, Family, Action, Comedy, Music, Adven...
# 5670  [Comedy, Franky, and, Krimo, dream, of, leavin...
# 5671  [Comedy, Stuck, in, the, corridors, of, time,,...
# 5672  [Family, Animation, Romance, Comedy, A, closet...
# 5673  [Comedy, Hyperactive, teenager, Kelly, is, enr...
#
# [5663 rows x 9 columns]

# %%
df_movies = df_movies[['id', 'title', 'titulo', 'tags']]
df_movies['id'] = df_movies['id'].astype(int)
df_movies
# Out:
#           id                                           title  \
# 0        862                                       Toy Story
# 1       8844                                         Jumanji
# 2      11862                     Father of the Bride Part II
# 3        949                                            Heat
# 4      11860                                         Sabrina
# ...      ...                                             ...
# 5669  417320                                   Descendants 2
# 5670  277839  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671  248705                      The Visitors: Bastille Day
# 5672  455661                                  In a Heartbeat
# 5673   14008                                     Cadet Kelly
#
#                                               titulo  \
# 0                   Toy Story: Um Mundo de Aventuras
# 1                                            Jumanji
# 2                                  O Pai da Noiva II
# 3                                   Fogo Contra Fogo
# 4                                            Sabrina
# ...                                              ...
# 5669                                  Descendentes 2
# 5670  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5671                      The Visitors: Bastille Day
# 5672                             Num piscar de Olhos
# 5673                                    Cadete Kelly
#
#                                                    tags
# 0     [Animation, Comedy, Family, Led, by, Woody,, A...
# 1     [Adventure, Fantasy, Family, When, siblings, J...
# 2     [Comedy, Just, when, George, Banks, has, recov...
# 3     [Action, Crime, Drama, Thriller, Obsessive, ma...
# 4     [Comedy, Romance, An, ugly, duckling, having, ...
# ...                                                 ...
# 5669  [TVMovie, Family, Action, Comedy, Music, Adven...
# 5670  [Comedy, Franky, and, Krimo, dream, of, leavin...
# 5671  [Comedy, Stuck, in, the, corridors, of, time,,...
# 5672  [Family, Animation, Romance, Comedy, A, closet...
# 5673  [Comedy, Hyperactive, teenager, Kelly, is, enr...
#
# [5663 rows x 4 columns]

# %%
df_movies['tags'] = df_movies['tags'].apply(lambda x: ' '.join(x))
df_movies.reset_index(drop=True, inplace=True)
df_movies
# Out:
#           id                                           title  \
# 0        862                                       Toy Story
# 1       8844                                         Jumanji
# 2      11862                     Father of the Bride Part II
# 3        949                                            Heat
# 4      11860                                         Sabrina
# ...      ...                                             ...
# 5658  417320                                   Descendants 2
# 5659  277839  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5660  248705                      The Visitors: Bastille Day
# 5661  455661                                  In a Heartbeat
# 5662   14008                                     Cadet Kelly
#
#                                               titulo  \
# 0                   Toy Story: Um Mundo de Aventuras
# 1                                            Jumanji
# 2                                  O Pai da Noiva II
# 3                                   Fogo Contra Fogo
# 4                                            Sabrina
# ...                                              ...
# 5658                                  Descendentes 2
# 5659  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 5660                      The Visitors: Bastille Day
# 5661                             Num piscar de Olhos
# 5662                                    Cadete Kelly
#
#                                                    tags
# 0     Animation Comedy Family Led by Woody, Andy's t...
# 1     Adventure Fantasy Family When siblings Judy an...
# 2     Comedy Just when George Banks has recovered fr...
# 3     Action Crime Drama Thriller Obsessive master t...
# 4     Comedy Romance An ugly duckling having undergo...
# ...                                                 ...
# 5658  TVMovie Family Action Comedy Music Adventure W...
# 5659  Comedy Franky and Krimo dream of leaving the g...
# 5660  Comedy Stuck in the corridors of time, Godefro...
# 5661  Family Animation Romance Comedy A closeted boy...
# 5662  Comedy Hyperactive teenager Kelly is enrolled ...
#
# [5663 rows x 4 columns]

# %%
vectorizer = CountVectorizer(max_features=5000, stop_words='english')

# %%
X = vectorizer.fit_transform(df_movies['tags']).toarray()

# %%
similarity = cosine_similarity(X)

# %%
pickle.dump(df_movies, open('lista_filmes.pkl', 'wb'))
pickle.dump(similarity, open('similarity.pkl', 'wb'))
